# %%
import pandas as pd

# %%
l = [x for x in range(5)]

# %%
series = pd.Series(l)

# %%
series
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
series[3]
# Out:
# 3

# %%
series = pd.Series(l, index=['a', 'b', 'c', 'd', 'e'])
series
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
series['c']
# Out:
# 2

# %%
series = pd.Series(l, index=['a', 'b', 'c', 'd', 'd'])
series['d']
# Out:
# d    3
# d    4
# dtype: int64

# %%
data = {'a':1, 'b':2, 'c':3, 'd':4}

# %%
series = pd.Series(data)

# %%
series
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
#taking 2 keys from the dictionary
series = pd.Series(data, index=['a', 'b'])

# %%
series
# Out:
# a    1
# b    2
# dtype: int64

# %% [markdown]
# Querying a Series

# %%
s = pd.Series([x for x in range(1,11)])

# %%
s.iloc[0]
# Out:
# 1

# %%
s.iat[8]
# Out:
# 9

# %%
s.where(s%2==0)
# Out:
# 0     NaN
# 1     2.0
# 2     NaN
# 3     4.0
# 4     NaN
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
s.where(s%2==0, 'odd')
# Out:
# 0    odd
# 1      2
# 2    odd
# 3      4
# 4    odd
# 5      6
# 6    odd
# 7      8
# 8    odd
# 9     10
# dtype: object

# %%
s.where(s%2==0,s**2)
# Out:
# 0     1
# 1     2
# 2     9
# 3     4
# 4    25
# 5     6
# 6    49
# 7     8
# 8    81
# 9    10
# dtype: int64

# %%
s.where(s%2==0, inplace=True)

# %%
#dropping null values
s.dropna(inplace=True)

# %%
s
# Out:
# 1     2.0
# 3     4.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
#filling null values
s.fillna('filled value', inplace=True)

# %%
s
# Out:
# 1     2.0
# 3     4.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %% [markdown]
# pandas DataFrames

# %%
df =  pd.read_csv('HousingData.csv', parse_dates=True)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
#multi level indexing
df.set_index(['CRIM', 'AGE'])
# Out:
#                  ZN  INDUS  CHAS    NOX     RM     DIS  RAD  TAX  PTRATIO  \
# CRIM    AGE
# 0.00632 65.2   18.0   2.31   0.0  0.538  6.575  4.0900    1  296     15.3
# 0.02731 78.9    0.0   7.07   0.0  0.469  6.421  4.9671    2  242     17.8
# 0.02729 61.1    0.0   7.07   0.0  0.469  7.185  4.9671    2  242     17.8
# 0.03237 45.8    0.0   2.18   0.0  0.458  6.998  6.0622    3  222     18.7
# 0.06905 54.2    0.0   2.18   0.0  0.458  7.147  6.0622    3  222     18.7
# ...             ...    ...   ...    ...    ...     ...  ...  ...      ...
# 0.06263 69.1    0.0  11.93   0.0  0.573  6.593  2.4786    1  273     21.0
# 0.04527 76.7    0.0  11.93   0.0  0.573  6.120  2.2875    1  273     21.0
# 0.06076 91.0    0.0  11.93   0.0  0.573  6.976  2.1675    1  273     21.0
# 0.10959 89.3    0.0  11.93   0.0  0.573  6.794  2.3889    1  273     21.0
# 0.04741 NaN     0.0  11.93   0.0  0.573  6.030  2.5050    1  273     21.0
#
#                     B  LSTAT  MEDV
# CRIM    AGE
# 0.00632 65.2   396.90   4.98  24.0
# 0.02731 78.9   396.90   9.14  21.6
# 0.02729 61.1   392.83   4.03  34.7
# 0.03237 45.8   394.63   2.94  33.4
# 0.06905 54.2   396.90    NaN  36.2
# ...               ...    ...   ...
# 0.06263 69.1   391.99    NaN  22.4
# 0.04527 76.7   396.90   9.08  20.6
# 0.06076 91.0   396.90   5.64  23.9
# 0.10959 89.3   393.45   6.48  22.0
# 0.04741 NaN    396.90   7.88  11.9
#
# [506 rows x 12 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=506, step=1)

# %%
df.loc[296]
# Out:
# CRIM         0.05372
# ZN           0.00000
# INDUS       13.92000
# CHAS         0.00000
# NOX          0.43700
# RM           6.54900
# AGE         51.00000
# DIS          5.96040
# RAD          4.00000
# TAX        289.00000
# PTRATIO     16.00000
# B          392.85000
# LSTAT        7.39000
# MEDV        27.10000
# Name: 296, dtype: float64

# %% [markdown]
# catergorical data

# %%
grades = pd.Series([87, 100, 94, 78, 100, 100, 94, 78, 81, 68, 100, 94])

# %%
grades
# Out:
# 0      87
# 1     100
# 2      94
# 3      78
# 4     100
# 5     100
# 6      94
# 7      78
# 8      81
# 9      68
# 10    100
# 11     94
# dtype: int64

# %%
grades.unique()
# Out:
# array([ 87, 100,  94,  78,  81,  68], dtype=int64)

# %% [markdown]
# plotting

# %%
df = pd.read_csv('houseprices.csv', parse_dates=True)
df.head()
# Out:
#   OrganisationLabel                                    OrganisationURI  \
# 0      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 1      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 2      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 3      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 4      Lincolnshire  http://opendatacommunities.org/id/county-counc...
#
#          PublishedDate LatestData         DurationFrom           DurationTo  \
# 0  2023-09-19T00:00:00       True  2023-06-01T00:00:00  2023-06-30T23:59:59
# 1  2023-09-19T00:00:00       True  2023-06-01T00:00:00  2023-06-30T23:59:59
# 2  2023-09-19T00:00:00       True  2023-06-01T00:00:00  2023-06-30T23:59:59
# 3  2023-09-19T00:00:00       True  2023-06-01T00:00:00  2023-06-30T23:59:59
# 4  2023-09-19T00:00:00       True  2023-06-01T00:00:00  2023-06-30T23:59:59
#
#   ReportingPeriodType    Month     GeoEntityName    GeoCode         GeoName  \
# 0               Month  2023-06            County  E10000019    Lincolnshire
# 1               Month  2023-06  District Council  E07000136          Boston
# 2               Month  2023-06  District Council  E07000137    East Lindsey
# 3               Month  2023-06  District Council  E07000138         Lincoln
# 4               Month  2023-06  District Council  E07000139  North Kesteven
#
#                                               GeoURI  AveragePrice  \
# 0  http://statistics.data.gov.uk/doc/statistical-...        232489
# 1  http://statistics.data.gov.uk/doc/statistical-...        201682
# 2  http://statistics.data.gov.uk/doc/statistical-...        232778
# 3  http://statistics.data.gov.uk/doc/statistical-...        184909
# 4  http://statistics.data.gov.uk/doc/statistical-...        269892
#
#    AveragePriceDetached  AveragePriceSemiDetached  AveragePriceTerraced  \
# 0                310171                    206565                163054
# 1                278906                    173998                137448
# 2                289842                    198806                155303
# 3                300950                    202661                153569
# 4                329684                    223446                181455
#
#    AveragePriceFlatOrMaisonette  Unnamed: 17
# 0                        112135          NaN
# 1                         95974          NaN
# 2                        106114          NaN
# 3                        114721          NaN
# 4                        116978          NaN

# %%
import matplotlib as plt
df.columns
# Out:
# Index(['OrganisationLabel', 'OrganisationURI', 'PublishedDate', 'LatestData',
#        'DurationFrom', 'DurationTo', 'ReportingPeriodType', 'Month',
#        'GeoEntityName', 'GeoCode', 'GeoName', 'GeoURI', 'AveragePrice',
#        'AveragePriceDetached', 'AveragePriceSemiDetached',
#        'AveragePriceTerraced', 'AveragePriceFlatOrMaisonette', 'Unnamed: 17'],
#       dtype='object')

# %%
df.plot()
# Out:
# <Axes: >
